# %%
#Problem 1: Unique Words in a Sentence

sentence = input("Enter sentence: ")
words = sentence.split()
unique_words = set(words)  
print("Unique words count:", len(unique_words)) 
print("Unique words:", unique_words)
# Out:
# Unique words count: 5
# Unique words: {'is', 'python', 'easy', 'and', 'powerful'}

# %%
#Problem 2: Highest Salary from Employee Data

employees = {
    "Ravi": 75000,
    "Anita": 68000,
    "Kiran": 72000
}

high_salary = 0
high_employee = ""

for name, salary in employees.items():
    if salary > high_salary:
        high_salary = salary
        high_employee = name

print("Highest Salary:", high_employee, "-", high_salary)
# Out:
# Highest Salary: Ravi - 75000

# %%
#Problem 3: Find Maximum and Minimum Values

numbers = [45, 22, 89, 10, 66]

print("List:", numbers)
print("Max:", max(numbers))
print("Min:", min(numbers))
# Out:
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %%
#Problem 4: Count Products Above a Price Threshold

prices = [450, 1200, 899, 1500, 300]

count = sum(1 for price in prices if price > 1000)

print("Products above 1000:", count)
# Out:
# Products above 1000: 2

# %%
#Problem 5: Calculate Attendance Percentage

attendance = ["P", "P", "A", "P", "P"]

presentC = attendance.count("P")
percentage = (presentC / len(attendance)) * 100

print("Attendance Percentage:", percentage)
# Out:
# Attendance Percentage: 80.0

# %%
#Problem 6: Remove Duplicate Phone Numbers

phone_numbers = [9876543210, 9123456789, 9876543210, 9123456789, 9988776655]

unique_numbers = set(phone_numbers)

print("Unique phone numbers:", unique_numbers)
# Out:
# Unique phone numbers: {9876543210, 9123456789, 9988776655}

# %%
#Problem 7: Count Character Frequency

word = "python"

char_count = {}

for ch in word:
    if ch in char_count:
        char_count[ch] += 1
    else:
        char_count[ch] = 1

print(char_count)
# Out:
# {'p': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %%
#Problem 8: Convert List to Tuple

numbers = [10, 20, 30]

converted_tuple = tuple(numbers)

print("Tuple:", converted_tuple)
print("Type:", type(converted_tuple))
# Out:
# Tuple: (10, 20, 30)
# Type: <class 'tuple'>

# %%
#Problem 9: Check if a Key Exists in a Dictionary

employees = {
    "Ravi": 75000,
    "Anita": 68000,
    "Kiran": 72000
}

target = "Ravi"

if target in employees:
    print("Employee exists")
else:
    print("Employee does not exist")
# Out:
# Employee exists

# %%
#Problem 10: Calculate Average Marks

marks = [70, 75, 80, 65]

average = sum(marks) / len(marks)

print("Average Marks:", average)
# Out:
# Average Marks: 72.5
